# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
# !pip show llama_cpp_python
# Out:
# Name: llama_cpp_python
# Version: 0.3.16
# Summary: Python bindings for the llama.cpp library
# Home-page: https://github.com/abetlen/llama-cpp-python
# Author:
# Author-email: Andrei Betlen <abetlen@gmail.com>
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: diskcache, jinja2, numpy, typing-extensions
# Required-by:

# %%
# !pip install --upgrade --force-reinstall --no-cache-dir https://github.com/abetlen/llama-cpp-python/releases/download/v0.3.16-cu124/llama_cpp_python-0.3.16-cp312-cp312-linux_x86_64.whl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 551.3/551.3 MB 35.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 230.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 249.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 359.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 157.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 274.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.3
# ...

# %%
from llama_cpp import llama_print_system_info
print(llama_print_system_info())
# Out:
# ggml_cuda_init: GGML_CUDA_FORCE_MMQ:    yes
# ggml_cuda_init: GGML_CUDA_FORCE_CUBLAS: no
# ggml_cuda_init: found 1 CUDA devices:
#   Device 0: NVIDIA L4, compute capability 8.9, VMM: yes
# b'CUDA : ARCHS = 500,520,530,600,610,620,700,720,750,800,860,870,890,900 | FORCE_MMQ = 1 | USE_GRAPHS = 1 | PEER_MAX_BATCH_SIZE = 128 | CPU : SSE3 = 1 | SSSE3 = 1 | AVX = 1 | AVX2 = 1 | F16C = 1 | FMA = 1 | BMI2 = 1 | LLAMAFILE = 1 | OPENMP = 1 | REPACK = 1 | '

# %%
#/content/drive/MyDrive/phi

# %%
# Install ngrok
# !pip install pyngrok

# %%
# To securely store your ngrok authtoken, use Colab's secrets management.
# Click the '🔑' icon in the left sidebar, then add your NGROK_AUTH_TOKEN.

from google.colab import userdata
from pyngrok import ngrok

NGROK_AUTH_TOKEN='36iETkd91z6iixXywnV08NA9m0C_o8iFsiUqCh2VwG9zDiiA'
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

print("ngrok authtoken set.")
# Out:
# ngrok authtoken set.

# %%
# import os
# os.chdir('/content/drive/MyDrive/phi')
# print('Starting server.py in background...')
# !python server.py &


import os
import subprocess

os.chdir('ui/phi_model_UI/')
server_process = subprocess.Popen(
    ['python', 'server.py'],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
    text=True
)

print(f"Server started in background with PID: {server_process.pid}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2614499934.py in <cell line: 0>()
#       8 import subprocess
#       9
# ---> 10 os.chdir('ui/phi_model_UI/')
#      11 server_process = subprocess.Popen(
#      12     ['python', 'server.py'],
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ui/phi_model_UI/'

# %%
from pyngrok import ngrok
import time
time.sleep(5)
ngrok.kill()
public_url = ngrok.connect(8000)
print(f"ngrok tunnel is active: {public_url}")
# Out:
# ngrok tunnel is active: NgrokTunnel: "https://banded-idella-premorbidly.ngrok-free.dev" -> "http://localhost:8000"

# %%
ngrok.kill()

# %%
# !ps -ef | grep server.py
# Out:
# root        2350    1078  0 20:20 ?        00:00:00 /bin/bash -c ps -ef | grep server.py
# root        2352    2350  0 20:20 ?        00:00:00 grep server.py

# %%
# !kill 1992
# !kill 6390
